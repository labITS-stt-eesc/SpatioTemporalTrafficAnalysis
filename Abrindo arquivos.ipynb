# %%
import pickle
import networkx as nx

# %%
#lê o aquivo no modo "rb" (read bits). O arquivo é um objeto do NetworkX
G = pickle.load(open('São Carlos.graph','rb'))

# %%
#plotando o grafo (precisa da biblioteca do Boeing)
import osmnx as ox

ox.plot_graph(G)
# Out:
# (<Figure size 470.846x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x16f15444b48>)
